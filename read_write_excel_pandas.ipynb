# %% [markdown]
# Vamos carregar as bibliotecas necessárias
#
# pandas vai ler os dados da planilha excel usando o openpyxl porque este
# consegue ler os formatos mais novos.

# %%
import pandas as pd
import openpyxl
from pathlib import Path
from IPython.display import display

# %%
xlsx_file = Path('cansaco_homeoffice_dataset_joao_blue.xlsx')
print(f'Acabei de ler xlsx_file com tipo {type(xlsx_file)}')
workbook_excel = pd.read_excel(io=xlsx_file)
print(f'Acabei de ler workbook_excel com tipo {type(workbook_excel)}')
print(workbook_excel)
# Out:
# Acabei de ler xlsx_file com tipo <class 'pathlib.PosixPath'>
# Acabei de ler workbook_excel com tipo <class 'pandas.core.frame.DataFrame'>
#     Qual a sua idade?                                 Qual o seu gênero?  \
# 0          18-22 anos  Homem Cisgênero (o indivíduo que se identifica...
# 1          23-27 anos  Mulher Cisgênero (se identifica com o sexo bio...
# 2          28-30 anos  Homem Cisgênero (o indivíduo que se identifica...
# 3          18-22 anos  Mulher Cisgênero (se identifica com o sexo bio...
# 4          36-38 anos  Mulher Cisgênero (se identifica com o sexo bio...
# ..                ...                                                ...
# 413        18-22 anos  Mulher Cisgênero (se identifica com o sexo bio...
# 414        23-27 anos  Mulher Cisgênero (se identifica com o sexo bio...
# 415        23-27 anos  Homem Cisgênero (o indivíduo que se identifica...
# 416        28-30 anos  Mulher Cisgênero (se identifica com o sexo bio...
# ...

# %%
workbook_excel.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>
