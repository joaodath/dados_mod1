# %%
import pandas as pd

# %%
df = pd.read_csv('dados_tratados.csv')
df
# Out:
#      data_nasc                localidade           time biscoito_bolacha  \
# 0   1995-05-07              São Paulo/SP      Palmeiras          BOLACHA
# 1   1989-06-27               Teresina/PI     4 de julho          BOLACHA
# 2   1989-12-02         Rio de Janeiro/RJ          Vasco         BISCOITO
# 3   1989-06-15               Redenção/CE            NaN          BOLACHA
# 4   1982-06-16              São Paulo/SP      São Paulo          BOLACHA
# 5   1992-11-30              Esperança/PB       Flamengo         BISCOITO
# 6   1996-06-17              Paranaguá/PR            não          BOLACHA
# 7   1984-12-28                Limeira/SP   VAI CURINTIA          BOLACHA
# 8   1984-07-31                  Natal/RN            não         BISCOITO
# 9   1994-10-06            Arvorezinha/RS  Internacional          BOLACHA
# 10  1985-09-18              São Paulo/SP       Cruzeiro         BISCOITO
# 11  1996-10-26  São Bernardo do Campo/SP            não         BISCOITO
# ...
