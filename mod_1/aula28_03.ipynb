# %%
import pandas as pd
from IPython.display import display

# %%
df = pd.read_excel('dados.xlsx')
#display(df)
df.describe()
# Out:
# /tmp/ipykernel_17058/2292829773.py:3: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe()
#                              Nome Data de Nascimento (DD/MM/AAAA)  \
# count                          24                              24
# unique                         24                              24
# top     Guilherme Muzzi da Rochas             1995-05-07 00:00:00
# freq                            1                               1
# first                         NaN             1979-03-25 00:00:00
# last                          NaN             2003-03-30 00:00:00
#
#        Onde mora? (cidade/estado) Time de futebol? Biscoito ou bolacha?  \
# count                          24               22                   24
# ...

# %%
df.tail()
# Out:
#                                  Nome Data de Nascimento (DD/MM/AAAA)  \
# 27                                NaN                             NaT
# 28                                NaN                             NaT
# 29                                NaN                             NaT
# 30  Cicero Rogério Lima Tenório Filho                      2003-03-10
# 31             João Paulo Souza Silva                      2003-03-30
#
#    Onde mora? (cidade/estado) Time de futebol? Biscoito ou bolacha?  \
# 27                        NaN              NaN                  NaN
# 28                        NaN              NaN                  NaN
# 29                        NaN              NaN                  NaN
# 30                  Maceió/AL              Não              Bolacha
# 31              Uberlândia/MG              NaN             Biscoito
#
#    arroz por cima, por baixo ou do lado do feijão? Ovo com gema dura ou mole?  \
# ...

# %%
df['Biscoito ou bolacha?'].value_counts()
# Out:
# Bolacha       9
# Biscoito      9
# bolacha       4
# Biscoito      1
# biscoito      1
# Name: Biscoito ou bolacha?, dtype: int64
